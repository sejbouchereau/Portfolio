# %% [markdown]
# # 🎯 Strategy Document

# %% [markdown]
# - **BI Professional**: Samuel Bouchereau
# - **Course**: Google Professional Certificate in Business Intelligence
# - **Client/Sponsor**: Google Fiber
# - **Project**: Repeat Caller Analysis (Call Center Data)
# - **Date**: November 2025

# %% [markdown]
# ## 1. Sign-Off Matrix
#
# | Name              | Team / Role | Date       |
# |-------------------|-------------|------------|
# | Samuel Bouchereau | BI Analyst  | 01/11/2025 |
#
# **Status:** Draft > Under review > `Implemented` | Not implemented

# %% [markdown]
# ## 2. Primary Dataset
# - Dataset is **fictionalized** and **anonymized**, based on actual Google Fiber call center data.
# - Customer call records including:
#   - Number of calls
#   - Number of repeat calls
#   - Call type
#   - Market city
#   - Contact dates

# %% [markdown]
# ## 3. User Profiles
# - Emma Santiago (Hiring Manager)
# - Keith Portone (Project Manager)
# - Minna Rah (Lead BI Analyst)
# - BI team members (Ian Ortega, Sylvie Essa)

# %% [markdown]
# ## 4. Dashboard Functionality
# | Feature                        | Request / Notes                                                                                                                 |
# |--------------------------------|---------------------------------------------------------------------------------------------------------------------------------|
# | **Reference Dashboard**        | N/A                                                                                                                             |
# | **Access**                     | Access restricted to authorized stakeholders only.                                                                              |
# | **Scope**                      | Number of calls, number of repeat calls, call type, market city, date                                                           |
# | **Date Filters & Granularity** | **Daily, weekly, monthly, quarterly, yearly** timescales. <br/> Provide a granularity drop-down with default set to **weekly**. |

# %% [markdown]
# ## 5. Metrics and Charts

# %% [markdown]
# ### Chart 1 — Repeat Calls by First Contact
# | Chart Feature | Your Request                                  |
# |---------------|-----------------------------------------------|
# | Chart title   | Repeat Calls by First Contact                 |
# | Chart type    | Bar chart                                     |
# | Dimension(s)  | Customer ID / Username                        |
# | Metric(s)     | Number of total calls, Number of repeat calls |
# | Notes         | Shows frequency of repeat calls per customer  |

# %% [markdown]
# ### Chart 2 — Repeat Calls by Market and Problem Type
# | Chart Feature | Your Request                                      |
# |---------------|---------------------------------------------------|
# | Chart title   | Repeat Calls by Market and Problem Type           |
# | Chart type    | Bar chart                                         |
# | Dimension(s)  | Market city, Problem type                         |
# | Metric(s)     | Number of repeat calls by market and problem type |
# | Notes         | Highlights trends by location and issue type      |

# %% [markdown]
# ### Chart 3 — Trend Analysis Over Time
# | Chart Feature | Your Request                                  |
# |---------------|-----------------------------------------------|
# | Chart title   | Trend Analysis Over Time                      |
# | Chart type    | Line chart                                    |
# | Dimension(s)  | Week, Month, Quarter, Year                    |
# | Metric(s)     | Number of repeat calls                        |
# | Notes         | Enables stakeholders to view trends over time |

# %% [markdown]
# ### Chart 4 — Contact Methods and Frequency
# | Chart Feature | Your Request                                                               |
# |---------------|----------------------------------------------------------------------------|
# | Chart title   | Contact Methods and Frequency                                              |
# | Chart type    | Bar / Pie chart                                                            |
# | Dimension(s)  | Contact type (phone, email, chat)                                          |
# | Metric(s)     | Counts of each contact type                                                |
# | Notes         | Shows how customers reach support and which channels generate repeat calls |
